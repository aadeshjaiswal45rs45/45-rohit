# %% [markdown]
# <a href="https://colab.research.google.com/github/aadeshjaiswal45rs45/45-rohit/blob/main/quickstarts/Get_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2026 Google LLC.

# %%
print ("good morning")
# Out:
# good morning

# %%
print(10+20)
# Out:
# 30

# %%
a=5
b=5
print(a+b)
print(a*b)
# Out:
# 10
# 25

# %%
a=5
b=3
print(a>b)
print(a<b)
# Out:
# True
# False

# %%
name2= input("entre a name =")
print(name2)
# Out:
# entre a name =rushi
# rushi

# %%
a= float(input("entre number"))
print(a,type(a))
b= float(input("entre another number"))
print(b,type(b))
print(a+b)
print(b-a)
# Out:
# entre number2
# 2.0 <class 'float'>
# entre another number1
# 1.0 <class 'float'>
# 3.0
# -1.0

# %%
print(5>2) and (2>1)
print(5>2) or (2<1)
a= (5>2 and 2>1) or(5>2 or 2<1)
print(a)
print(5<2) or (2>1)
# Out:
# True
# True
# True
# False
# True

# %%
mark = int(input("enter mark="))
if mark>50:
  print("pass")
else:
  print("fail")
# Out:
# enter mark=78
# pass
